# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("dataset/train.csv")

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 412          413         1       1
# 648          649         0       3
# 408          409         0       3
# 231          232         0       3
# 849          850         1       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 412                        Minahan, Miss. Daisy E  female  33.0      1      0
# 648                            Willey, Mr. Edward    male   NaN      0      0
# 408             Birkeland, Mr. Hans Martin Monsen    male  21.0      0      0
# 231                      Larsson, Mr. Bengt Edvin    male  29.0      0      0
# 849  Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female   NaN      1      0
#
#             Ticket     Fare Cabin Embarked
# 412          19928  90.0000   C78        Q
# 648  S.O./P.P. 751   7.5500   NaN        S
# 408         312992   7.7750   NaN        S
# 231         347067   7.7750   NaN        S
# 849          17453  89.1042   C92        C

# %% [markdown]
# # 1. Categorical Data
#
# ## a. Countplot

# %%
# sns.countplot(df['Embarked'])
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
# sns.countplot(df['Embarked'])
import matplotlib.pyplot as plt
sns.countplot(x ='Embarked', data = df)
plt.show()
# sns.countplot(x ='sex', data = df)

# %% [markdown]
# # 2.Piechart

# %%
df['Age'].value_counts().plot(kind='pie',autopct='%.2f')
df['Sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Sex'>

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Pclass'>

# %% [markdown]
# # 2. Numerical Data
# ## a. Histogram

# %%
plt.hist(df['Age'],bins=20)
# Out:
# (array([40., 14., 15., 31., 79., 98., 85., 84., 73., 45., 35., 35., 29.,
#         16., 13., 11.,  4.,  5.,  1.,  1.]),
#  array([ 0.42 ,  4.399,  8.378, 12.357, 16.336, 20.315, 24.294, 28.273,
#         32.252, 36.231, 40.21 , 44.189, 48.168, 52.147, 56.126, 60.105,
#         64.084, 68.063, 72.042, 76.021, 80.   ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(df['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # b. DISTPLOT

# %%
sns.displot(df['Age'])

# %%
sns.distplot(df['Age'])

#probablity density function
# Out:
# C:\Users\ALOK SINGH\AppData\Local\Temp\ipykernel_3712\1437367865.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.histplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# # c.BOXPLOT

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: >

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].skew()
# Out:
# 0.38910778230082704

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df1=pd.read_csv("dataset/trains vs planes.csv")

# %%
df1.head()
# Out:
#     Mode         Route  week  Ticket Price       date
# 0  Plane  mumbai-delhi     1          5942  30-01-2022
# 1  Plane  mumbai-delhi     2          5942  06-02-2022
# 2  Plane  mumbai-delhi     3          2339  13-02-2022
# 3  Plane  mumbai-delhi     4          2336  20-02-2022
# 4  Plane  mumbai-delhi     5          2336  27-02-2022

# %%
df1['Route'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df1['Mode'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df1['Mode'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Mode'>

# %%
df2=pd.read_csv("dataset/Suicides in India 2001-2012.csv")

# %%
df2
# Out:
#                 State  Year      Type_code  \
# 0       A & N Islands  2001         Causes
# 1       A & N Islands  2001         Causes
# 2       A & N Islands  2001         Causes
# 3       A & N Islands  2001         Causes
# 4       A & N Islands  2001         Causes
# ...               ...   ...            ...
# 237514    West Bengal  2012  Social_Status
# 237515    West Bengal  2012  Social_Status
# 237516    West Bengal  2012  Social_Status
# 237517    West Bengal  2012  Social_Status
# 237518    West Bengal  2012  Social_Status
#
#                                            Type  Gender Age_group  Total
# 0                            Illness (Aids/STD)  Female      0-14      0
# 1       Bankruptcy or Sudden change in Economic  Female      0-14      0
# 2       Cancellation/Non-Settlement of Marriage  Female      0-14      0
# 3             Physical Abuse (Rape/Incest Etc.)  Female      0-14      0
# 4                                 Dowry Dispute  Female      0-14      0
# ...

# %%
df2['State'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df2['Year'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df2['Gender'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Gender'>

# %%
plt.hist(df2['Age_group'])
# Out:
# (array([45027.,     0., 45223.,     0., 45193.,     0., 45146.,     0.,
#         45074., 11856.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)
